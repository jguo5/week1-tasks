# %% [markdown]
# # Tutorial 3: Reading and Writing CSV files with Python
#
# This tutorial can be found in this link: [RealPython CSV Files Tutorial](https://realpython.com/python-csv/).
#
# **Note:** Use Markdown headings to create sections in the notebook. Run each snippet of code in one cell.

# %% [markdown]
# ## 1. Reading CSV Files With `csv`
# comma separated values file
# printable ASCII or unicode characters

# %%
#read csv files
import csv

with open('employee_birthday.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            print(f'\t{row[0]} works in the {row[1]} department, and was born in {row[2]}.')
            line_count += 1
    print(f'Processed {line_count} lines.')
# Out:
# Column names are name, department, birthday month
# 	John Smith works in the Accounting department, and was born in November.
# 	Erica Meyers works in the IT department, and was born in March.
# Processed 3 lines.

# %%
#read csv into dict

with open('employee_birthday.csv', mode='r') as csv_file:
    csv_reader = csv.DictReader(csv_file)
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        print(f'\t{row["name"]} works in the {row["department"]} department, and was born in {row["birthday month"]}.')
        line_count += 1
    print(f'Processed {line_count} lines.')
# Out:
# Column names are name, department, birthday month
# 	John Smith works in the Accounting department, and was born in November.
# 	Erica Meyers works in the IT department, and was born in March.
# Processed 3 lines.

# %% [markdown]
# deal with commas within text and not between obj:
# use different delimiter, wrap data in quotes `quotechar`, escape delimiter characters in data `escapechar`

# %%
# write files csv

with open('employee_file.csv', mode='w') as employee_file:
    employee_writer = csv.writer(employee_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)

    employee_writer.writerow(['John Smith', 'Accounting', 'November'])
    employee_writer.writerow(['Erica Meyers', 'IT', 'March'])

#write from dict

with open('employee_file2.csv', mode='w') as csv_file:
    fieldnames = ['emp_name', 'dept', 'birth_month']
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)

    writer.writeheader()
    writer.writerow({'emp_name': 'John Smith', 'dept': 'Accounting', 'birth_month': 'November'})
    writer.writerow({'emp_name': 'Erica Meyers', 'dept': 'IT', 'birth_month': 'March'})

# %% [markdown]
# ## 3. Parse CSV with `pandas` library

# %%
#pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\iwuba\appdata\local\programs\python\python311\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\iwuba\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.3.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\iwuba\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\iwuba\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\iwuba\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\iwuba\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas
df = pandas.read_csv('hrdata.csv')
print(df)
# Out:
#              Name Hire Date   Salary  Sick Days remaining
# 0  Graham Chapman  03/15/14  50000.0                   10
# 1     John Cleese  06/01/15  65000.0                    8
# 2       Eric Idle  05/12/14  45000.0                   10
# 3     Terry Jones  11/01/13  70000.0                    3
# 4   Terry Gilliam  08/12/14  48000.0                    7
# 5   Michael Palin  05/23/13  66000.0                    8

# %%
#use a different column as df index
df = pandas.read_csv('hrdata.csv', index_col='Name')
print(df)

#if no column name in first line
df = pandas.read_csv('hrdata.csv', 
            index_col='Employee', 
            parse_dates=['Hired'], 
            header=0, 
            names=['Employee', 'Hired','Salary', 'Sick Days'])
print(df)
# Out:
#                Hire Date   Salary  Sick Days remaining
# Name
# Graham Chapman  03/15/14  50000.0                   10
# John Cleese     06/01/15  65000.0                    8
# Eric Idle       05/12/14  45000.0                   10
# Terry Jones     11/01/13  70000.0                    3
# Terry Gilliam   08/12/14  48000.0                    7
# Michael Palin   05/23/13  66000.0                    8
#                     Hired   Salary  Sick Days
# Employee
# Graham Chapman 2014-03-15  50000.0         10
# John Cleese    2015-06-01  65000.0          8
# Eric Idle      2014-05-12  45000.0         10
# Terry Jones    2013-11-01  70000.0          3
# Terry Gilliam  2014-08-12  48000.0          7
# Michael Palin  2013-05-23  66000.0          8
# C:\Users\iwuba\AppData\Local\Temp\ipykernel_19936\1367010150.py:6: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pandas.read_csv('hrdata.csv',

# %%
#Write csv with pandas
df = pandas.read_csv('hrdata.csv', 
            index_col='Employee', 
            parse_dates=['Hired'],
            header=0, 
            names=['Employee', 'Hired', 'Salary', 'Sick Days'])
df.to_csv('hrdata_modified.csv')
# Out:
# C:\Users\iwuba\AppData\Local\Temp\ipykernel_19936\1492770630.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pandas.read_csv('hrdata.csv',
